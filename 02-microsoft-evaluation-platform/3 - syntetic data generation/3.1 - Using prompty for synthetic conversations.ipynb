# %% [markdown]
# # [Generate synthetic and simulated data for evaluation](https://learn.microsoft.com/en-us/azure/ai-foundry/how-to/develop/simulator-interaction-data)
# The Azure AI Evaluation SDK `Simulator` generates synthetic conversations for testing an application before production data is available. It can use source text, predefined tasks, or custom callbacks to simulate non-adversarial interactions.
#
# This capability is useful for:
# - **Testing conversational applications:** Check how chatbots and assistants respond across representative scenarios.
# - **Creating evaluation datasets:** Produce conversation records for repeatable evaluation and analysis.
# - **Supporting model development:** Generate varied examples for experimentation and refinement.
#
# This notebook connects the simulator to a Prompty-based application and produces a small grounded conversation.

# %%
import os, sys, json
import prompty
import asyncio
from typing import Any, Dict, Optional
from pprint import pprint
from azure.identity import DefaultAzureCredential
from dotenv import load_dotenv  # requires python-dotenv

if not load_dotenv("./../credentials_my.env"):
    print("Environment variables not loaded, cell execution stopped")
    sys.exit()

ASSETS_FOLDER = "eval_assets"
GROUNDING_DATA_SOURCE_PATH = "../data/documents.txt"
PROMPTY_APP="conversation_simulation.prompty"

openai_api_version = os.environ["AZURE_OPENAI_API_VERSION"]
azure_openai_endpoint = os.environ["AZURE_OPENAI_ENDPOINT"]
foundry_project_endpoint = os.environ.get("FOUNDRY_PROJECT_ENDPOINT")

azure_openai_deployment_name = os.environ.get("AZURE_OPENAI_CHAT_DEPLOYMENT_NAME")

credential = DefaultAzureCredential()

print(f"azure_openai_endpoint: {azure_openai_endpoint}")
print(f"foundry_project_endpoint: {foundry_project_endpoint}")
print(f"azure_openai_deployment_name: {azure_openai_deployment_name}")
print(f"openai_api_version: {openai_api_version}")
# Out:
# azure_openai_endpoint: https://mm-ai-upskilling-project-resourc.openai.azure.com/
# foundry_project_endpoint: https://mm-ai-upskilling-project-resourc.services.ai.azure.com/api/projects/ai-upskilling-project
# azure_openai_deployment_name: gpt-5.4-mini
# openai_api_version: 2025-04-01-preview

# %%
# Initialize Azure OpenAI connection

from azure.ai.evaluation import AzureOpenAIModelConfiguration

model_config = AzureOpenAIModelConfiguration(
    azure_endpoint=azure_openai_endpoint,
    azure_deployment=azure_openai_deployment_name,
    api_version=openai_api_version,
)

# %% [markdown]
# ## Define the Conversation Simulation Prompty
# A `.prompty` file is a portable prompt asset composed of front matter that defines the model configuration and typed inputs, followed by the prompt template. The standalone `prompty` Python package loads the file, resolves the configuration and inputs, renders the template, and invokes the configured model.
#
# Prompty is independent of Microsoft Prompt flow: using the `prompty` package does not require Prompt flow, so Prompt flow's deprecation and retirement lifecycle does not apply to this execution approach. In this example, the conversation history is declared as a `thread`, allowing Prompty to insert prior messages before the current user query.

# %%
with open(f"{ASSETS_FOLDER}/{PROMPTY_APP}", "w") as f:
    f.write("""---
name: ConversationSimulationPrompty
description: Chat application for simulating a conversatation
model:
    id: ${env:AZURE_OPENAI_CHAT_DEPLOYMENT_NAME}
    provider: foundry
    connection:
        kind: foundry
        endpoint: ${env:FOUNDRY_PROJECT_ENDPOINT}
    options:
        temperature: 0.0
        top_p: 1.0
inputs:
    - name: context
      kind: string
    - name: query
      kind: string
    - name: conversation_history
      kind: thread
template:
    format:
        kind: jinja2
    parser:
        kind: prompty
---
system:
You are a helpful assistant and you're helping with the user's query.
Keep the conversation engaging and interesting.
{{ conversation_history }}

user:
Keep your answer grounded in the provided context:
{{ context }}

Continue the conversation by responding to this query:
{{ query }}""")

# %% [markdown]
# ## Test the prompty application

# %%
prompty_path = f"./{ASSETS_FOLDER}/{PROMPTY_APP}"

# Keep direct Prompty execution behind a small application-style function.
def run_application(*, context: str, query: str, conversation_history: list[dict]) -> str:
    return prompty.invoke(
        prompty_path,
        inputs={
            "conversation_history": conversation_history,
            "context": context,
            "query": query,
        },
    )

# Run a simple smoke test before connecting the application to the Simulator.
pprint(run_application(context="", query="How to make a pizza at home", conversation_history=[]))
# Out:
# ('Making pizza at home is pretty straightforward. Here’s a simple way:\n'
#  '\n'
#  '### Ingredients\n'
#  '- Pizza dough\n'
#  '- Tomato sauce\n'
#  '- Mozzarella cheese\n'
#  '- Toppings you like: pepperoni, vegetables, mushrooms, onions, etc.\n'
#  '- Olive oil\n'
#  '- Flour or cornmeal for dusting\n'
#  '\n'
#  '### Steps\n'
#  '1. **Preheat the oven**  \n'
#  '   Set your oven to **475°F to 500°F (245°C to 260°C)**. If you have a pizza '
#  'stone or baking sheet, let it heat up too.\n'
#  '\n'
#  '2. **Prepare the dough**  \n'
#  '   Roll or stretch the dough on a floured surface into your desired shape.\n'
#  '\n'
#  '3. **Add sauce**  \n'
#  '   Spread a thin layer of tomato sauce over the dough, leaving a small '
#  'border around the edges.\n'
#  '\n'
#  '4. **Add cheese and toppings**  \n'
#  '   Sprinkle mozzarella evenly, then add your toppings. Don’t overload it or '
#  'the pizza may get soggy.\n'
#  '\n'
#  '5. **Bake**  \n'
#  '   Transfer the pizza to the oven and bake for about **10–15 minutes**, or '
#  'until the crust is golden and the cheese is bubbly.\n'
#  '\n'
#  '6. **Finish and serve**  \n'
#  '   Let it cool for a minute or two, slice it, and enjoy.\n'
#  '\n'
#  'If you want, I can also give you:\n'
#  '- a **homemade dough recipe**\n'
#  '- a **no-yeast pizza recipe**\n'
#  '- or a **pan pizza version**')

# %%
# friendly_conversation_history_en.txt or friendly_conversation_history_it.txt
with open(f"./{ASSETS_FOLDER}/friendly_conversation_history_en.txt", "r", encoding="utf-8") as f:
    conversation_history = json.load(f)
    
conversation_history
# Out:
# [{'content': "Let's talk in English, with answers shorter than 30 words on a single line. What are you up to this evening?",
#   'role': 'user',
#   'context': 'Friendly question between two friends or relatives.'},
#  {'content': "I'm going to the cinema",
#   'role': 'assistant',
#   'context': 'Description of a fun recreational activity this person is going to have this evening.'},
#  {'content': 'Ah fantastic! What are you going to see?',
#   'role': 'user',
#   'context': 'Follow-up friendly question showing interest in the other person.'},
#  {'content': "I'm going to see **Jaws** by Steven Spielberg. Should be a classic!",
#   'role': 'assistant',
#   'context': 'Final additional details about the fun activity. Now propose a new topic to discuss, connected to this one.'}]

# %%
i = 0
for ch in conversation_history:
    print(f'Message {i} ({ch["role"]}): {ch["content"]}')    
    i = i+1

response = run_application(
    context=conversation_history[-1]["context"],
    query=conversation_history[-1]["content"],
    conversation_history=conversation_history[:-1],
)

print(f"\nMessage {i} ({ch["role"]}): {response}")
# Out:
# Message 0 (user): Let's talk in English, with answers shorter than 30 words on a single line. What are you up to this evening?
# Message 1 (assistant): I'm going to the cinema
# Message 2 (user): Ah fantastic! What are you going to see?
# Message 3 (assistant): I'm going to see **Jaws** by Steven Spielberg. Should be a classic!
#
# Message 4 (assistant): Great choice—Jaws is a classic thriller. What’s your favorite Spielberg film?

# %% [markdown]
# ## Generate and append one additional turn to the sample conversation.
# Feel free to run the next cell multiple times, to show how the conversation cotinues

# %%
# Generate and append one additional turn to the sample conversation.

next_role = "user" if conversation_history[-1]["role"] == "assistant" else "assistant"
conversation_history.append({"content": response, "role": next_role, "context": ""})

for index, message in enumerate(conversation_history):
    print(f'Message {index} ({message["role"]}): {message["content"]}')

response = run_application(
    context=conversation_history[-1]["context"],
    query=conversation_history[-1]["content"],
    conversation_history=conversation_history[:-1],
)

print(f'\nMessage {len(conversation_history)} ({conversation_history[-2]["role"]}): {response}')
# Out:
# Message 0 (user): Let's talk in English, with answers shorter than 30 words on a single line. What are you up to this evening?
# Message 1 (assistant): I'm going to the cinema
# Message 2 (user): Ah fantastic! What are you going to see?
# Message 3 (assistant): I'm going to see **Jaws** by Steven Spielberg. Should be a classic!
# Message 4 (user): Great choice—Jaws is a classic thriller. What’s your favorite Spielberg film?
# Message 5 (assistant): My favorite Spielberg film is **E.T. the Extra-Terrestrial**—it’s heartfelt, magical, and timeless.
# Message 6 (user): E.T. is a wonderful choice—warm, imaginative, and unforgettable.
# Message 7 (assistant): Absolutely—its emotional core and sense of wonder make it special. What Spielberg film do you love most?
#
# Message 8 (user): I’d pick **E.T. the Extra-Terrestrial** too—it’s Spielberg at his most heartfelt and magical.

# %% [markdown]
# ## Define the Simulator callback
# The callback implements the same mechanism demonstrated manually above, adapted to the interface expected by the `Simulator`. It separates the latest message from the preceding conversation history, extracts its grounding context, resolves the path to the Prompty file, and invokes it with the query, context, and history as inputs. It then appends the generated assistant response and returns the conversation using the chat protocol expected by the Evaluation SDK.
#
# > **Prompty v2 beta compatibility note:** This workshop pins `prompty[foundry,jinja2]==2.0.0b3`, the version validated with this notebook. In this release, `prompty.invoke_async()` is not compatible with the Entra ID authentication path used by the Foundry provider: the asynchronous OpenAI client attempts to await a synchronous token provider and raises `TypeError: object str can't be used in 'await' expression`.
# >
# > The callback therefore runs the validated synchronous `prompty.invoke()` function through `asyncio.to_thread()`. This keeps the callback asynchronous without blocking the notebook event loop. When a later Prompty release fixes the asynchronous Entra ID token provider, test that release separately before changing the pinned dependency and replacing this workaround with `await prompty.invoke_async(...)`.

# %%
async def callback(
    messages: Dict[str, Any],
    stream: bool = False,
    session_state: Any = None,
    context: Optional[Dict[str, Any]] = None,
    assets_folder: str = ASSETS_FOLDER,
    prompty_app: str = PROMPTY_APP
) -> dict[str, Any]:
    
    messages_list = messages["messages"]
    latest_message = messages_list[-1]
    latest_context = latest_message.get("context") or ""
    application_prompty = os.path.join(os.getcwd(), assets_folder, prompty_app)

    # Run the synchronous Prompty call on a worker thread to keep this callback non-blocking.
    response = await asyncio.to_thread(
        prompty.invoke,
        application_prompty,
        inputs={
            "query": latest_message["content"],
            "context": latest_context,
            "conversation_history": messages_list[:-1],
        },
    )

    # Return the updated conversation in the protocol expected by the Simulator.
    messages_list.append(
        {
            "content": response,
            "role": "assistant",
            "context": latest_context,
        }
    )
    return {
        "messages": messages_list,
        "stream": stream,
        "session_state": session_state,
        "context": context,
    }

# %% [markdown]
# ## Prepare the grounding text
# For a deterministic workshop run, the example reads a local document instead of calling an external content API. The first 5,000 characters provide enough context for a short grounded conversation.

# %%
from pathlib import Path

# Limit the source text to keep the example fast and the prompt compact.
source_path = Path(GROUNDING_DATA_SOURCE_PATH)
source_text = source_path.read_text(encoding="utf-8")[:5000]
print(f"{source_text[:1000]}...")
# Out:
# "Bullet Kin
# Bullet Kin are one of the most common enemies. They slowly walk towards the player, occasionally firing a single bullet. They can flip tables and use them as cover. They will also deal contact damage if the player touches them.
#
# Occasionally, Bullet Kin will have assault rifles, in which case they will rapidly fire 8 bullets towards the player before reloading. When an assault rifle wielding bullet kin appears, there will often be more in the same room.
#
# On some occasions the player will also encounter incapacitated Bullet Kin lying on the floor. These Bullet Kin are props and disintegrate upon touch. They can be found in mass quantity in Oubliette.
#
# In the Black Powder Mine, they can also ride Minecarts. In fact, if there are any unoccupied Minecarts within the room, they will take priority by walking towards them to ride in.
#
# Trivia
# Bullet Kin wield Magnums. Assault-rifle wielding Bullet Kin wield AK-47s.
# Incapacitated Bullet Kin can be found in the Oublilette and Cannon'...

# %%
from azure.ai.evaluation.simulator import Simulator

class CompatibleSimulator(Simulator):
    """Normalize the wrapped Prompty output returned by Evaluation SDK 1.18.3."""

    def _parse_prompty_response(self, *, response: Any) -> Dict[str, Any]:
        parsed_response = super()._parse_prompty_response(response=response)
        if isinstance(parsed_response, dict) and "content" not in parsed_response:
            llm_output = parsed_response.get("llm_output")
            if isinstance(llm_output, str):
                parsed_response = super()._parse_prompty_response(response=llm_output)
            elif isinstance(llm_output, dict):
                parsed_response = llm_output
        if not isinstance(parsed_response, dict) or "content" not in parsed_response:
            raise ValueError(f"Unexpected user-simulator response: {parsed_response!r}")
        return parsed_response

# Use the compatibility subclass until the SDK unwraps llm_output internally.
simulator = CompatibleSimulator(model_config=model_config)
# Out:
# Class Simulator: This is an experimental class, and may change at any time. Please see https://aka.ms/azuremlexperimental for more information.

# %%
# Use a predefined user turn to make the first exchange deterministic.
seed_turns = [
    [
        {
            "content": "What are Bullet Kin and how do they behave?",
            "context": source_text,
        }
    ]
]

# Each conversation turn is one user/assistant pair; the user simulator generates turns after the seed.
outputs = await simulator(
    target=callback,
    conversation_turns=seed_turns,
    max_conversation_turns=5,
    api_call_delay_sec=0,
)
# Out:
# Simulating with predefined conversation turns: 100%|████████████| 5/5 [00:24<00:00,  4.98s/messages]

# %%
# Print the generated conversation in chronological order.
for index, message in enumerate(outputs[0]["messages"]):
    if (index==0):
        print(f"==========HERE ARE THE {len(outputs[0]["messages"])} GENERATED MESSAGES ==========\n")
    print(f'===== Message {index+1} by <{message["role"]}> =====')
    print(f'{message["content"]}\n\n')
# Out:
# ==========HERE ARE THE 10 GENERATED MESSAGES ==========
#
# ===== Message 1 by <user> =====
# What are Bullet Kin and how do they behave?
#
#
# ===== Message 2 by <assistant> =====
# Bullet Kin are one of the most common enemies. They slowly walk toward the player and occasionally fire a single bullet. They can also flip tables and use them as cover, and if the player touches them, they deal contact damage.
#
# Sometimes they appear with assault rifles, which lets them rapidly fire 8 bullets before reloading. When those versions show up, there are often more Bullet Kin in the room. In the Black Powder Mine, they can also ride minecarts if one is available.
#
# There are also incapacitated Bullet Kin lying on the floor as props; these disintegrate when touched.
#
#
# ===== Message 3 by <user> =====
# That’s helpful — do Bullet Kin have any weaknesses or reliable ways to deal with them quickly, especially the assault rifle versions or the minecart ones?
#
#
# ===== Message 4 by <assistant> =====
# I don’t have any grounded context here beyond the earlier description, so I can’t reliably say what their weaknesses are or give specific counter-strategies without guessing.
#
# From the context we do have, the safest inference is:
# - **Assault rifle Bullet Kin** are more dangerous because they can fire rapidly before reloading, so avoiding open lines of sight and using cover would be prudent.
# - **Minecart Bullet Kin** likely have the mobility advantage of the cart, so controlling space and not letting them close distance would be important.
#
# If you want, I can still help by giving a **careful, clearly labeled “best-practice” strategy** based only on those behaviors, without claiming any extra lore.
#
#
# ===== Message 5 by <user> =====
# Yes — please give me that careful best-practice strategy based only on the behaviors you described. Also, if you can, include a quick priority list for which Bullet Kin variants to focus first in a room.
#
#
# ===== Message 6 by <assistant> =====
# Based only on the behaviors described, a careful best-practice approach would be:
#
# - **Keep moving** so you’re harder to hit by their single shots or rapid bursts.
# - **Use cover aggressively**, especially against the assault rifle versions, since they can fire 8 bullets quickly before reloading.
# - **Avoid close contact**, since Bullet Kin deal contact damage if they touch you.
# - **Break line of sight when possible** so you can force them to reposition or waste shots.
# - **Use room objects and tables** to slow their advance, since they can flip tables too, but cover still helps you manage their approach.
#
# For the **assault rifle Bullet Kin**, the main danger is their burst fire, so they should be treated as a higher-priority threat than the basic version. Try to engage them from cover and punish them during reload windows.
#
# For the **minecart Bullet Kin**, the key is to avoid letting them use the cart to close distance or control space. If you can, focus them before they get too much momentum or before they can pressure you from an awkward angle.
#
# ### Priority list
# 1. **Assault rifle Bullet Kin** — highest priority because of rapid burst damage.
# 2. **Minecart Bullet Kin** — next priority because of their mobility and positional pressure.
# 3. **Regular Bullet Kin** — lower priority, since they only slowly advance and fire single shots.
#
# If you want, I can turn that into a very short “in-room decision guide” like: “what to do first, second, third” in one glance.
#
#
# ===== Message 7 by <user> =====
# Yes — a one-glance in-room decision guide would be great. Could you make it super short and practical, like a quick checklist I can follow during a fight? Also, if there are any common mistakes people make against Bullet Kin, I’d like to know those too.
#
#
# ===== Message 8 by <assistant> =====
# Sure — grounded only in the behaviors described:
#
# ### Quick in-room checklist
# - **See assault rifle Bullet Kin?** Focus it first.
# - **See minecart Bullet Kin?** Keep distance and watch its angle.
# - **See regular Bullet Kin?** Deal with it after the higher-threat ones.
# - **Always keep moving.**
# - **Use cover/tables when available.**
# - **Don’t let them touch you.**
# - **Punish them during reloads or after they commit to a shot.**
#
# ### Common mistakes
# - **Ignoring assault rifle versions** until they’ve already fired a burst.
# - **Standing still in open space** and taking easy shots.
# - **Getting too close** and eating contact damage.
# - **Forgetting they can use tables as cover**, which can make them harder to hit if you don’t reposition.
# - **Underestimating minecart versions** and letting them control the fight’s spacing.
#
# If you want, I can compress this even further into a 3-line “fight mantra.”
#
#
# ===== Message 9 by <user> =====
# Yes — please make the 3-line fight mantra. Also, could you clarify whether the assault rifle Bullet Kin should always be the first target even if a minecart one is already close to me?
#
#
# ===== Message 10 by <assistant> =====
# Absolutely — grounded only in the behaviors described:
#
# ### 3-line fight mantra
# - **Move constantly, don’t get touched.**
# - **Use cover, and punish reloads.**
# - **Kill the biggest threat first.**
#
# ### Target priority clarification
# Not **always**. If a **minecart Bullet Kin is already close to you**, that immediate proximity can make it the more urgent threat **in that moment**, because contact damage and space control become the bigger danger.
#
# So the practical rule is:
# - **Default:** focus the **assault rifle Bullet Kin** first.
# - **Exception:** if a **minecart one is already on top of you or about to force contact**, deal with that immediate threat first.
#
# In short: **prioritize the enemy that is most dangerous right now**, with assault rifle Bullet Kin usually being the top threat unless the minecart one has already closed the gap.
