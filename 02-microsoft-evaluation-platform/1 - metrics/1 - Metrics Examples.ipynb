# %% [markdown]
# # [Azure OpenAI Responses API's](https://learn.microsoft.com/en-us/azure/ai-services/openai/how-to/responses?tabs=python-secure#generate-a-text-response) (with Entra ID authentication)

# %%
import os, sys
from openai import AzureOpenAI
from dotenv import load_dotenv # requires python-dotenv
from azure.identity import DefaultAzureCredential, get_bearer_token_provider

if not load_dotenv("./../credentials_my.env"):
    print("Environment variables not loaded, cell execution stopped")
    sys.exit()

openai_api_version    = os.environ["AZURE_OPENAI_API_VERSION"]
azure_openai_endpoint = os.environ["AZURE_OPENAI_ENDPOINT"]
azure_deployment_name = os.environ["AZURE_OPENAI_CHAT_DEPLOYMENT_NAME"]
credential = DefaultAzureCredential()

LANGUAGE = "English" # "English", "Italian", "French", "Japanese"...

token_provider = get_bearer_token_provider(
    credential,
    "https://cognitiveservices.azure.com/.default",
)

client = AzureOpenAI(
    azure_ad_token_provider=token_provider,
    api_version=openai_api_version,
    azure_endpoint=azure_openai_endpoint
)

print(f"openai_endpoint: {client.base_url}")
print(f"azure_deployment_name: {azure_deployment_name}")
print(f"openai_api_version: {openai_api_version}")
# Out:
# openai_endpoint: https://mm-ai-upskilling-project-resourc.openai.azure.com/openai/
# azure_deployment_name: gpt-5.4-mini
# openai_api_version: 2025-04-01-preview

# %% [markdown]
# # Read the system message plus the json list of metrics

# %%
import json

# Open the system_message file in read mode
with open("system_message.txt", "r", encoding="utf-8") as file:
    system_message = file.read()

# Open the metrics file in read mode
with open("metrics.json", "r", encoding="utf-8") as file:
    metrics_list = json.loads(file.read().replace("\n", ""))

i=1
for m in metrics_list:
    print (f'{i}: {m["metric_name"]}')
    i += 1
# Out:
# 1: Intent Resolution
# 2: Tool Call Accuracy
# 3: Task Adherence
# 4: Response Completeness
# 5: Groundedness (prompt-based)
# 6: Groundedness Pro
# 7: Retrieval
# 8: Relevance
# 9: Coherence
# 10: Fluency
# 11: Similarity
# 12: F1 Score
# 13: BLEU Score
# 14: ROUGE Score
# 15: METEOR Score

# %% [markdown]
# # You may run the next cell multiple times to explore metrics samples

# %%
from IPython.display import Markdown, display

index = int(input("Which metric would you like to analyze?"))

display(Markdown(f"\n\n**GREAT CHOICE!** Here are a couple examples for the metric `<{metrics_list[index-1]['metric_name']}>`\n"))

messages=[{"role": "system", "content": f"{system_message}.\nQUESTION, ANSWER, SCORE AND  EXPLANATION must be in {LANGUAGE}"},
          {"role": "user", "content": json.dumps(metrics_list[index-1])}]

response = client.responses.create(
    model=os.environ['AZURE_OPENAI_CHAT_DEPLOYMENT_NAME'],
    input=messages)

display(Markdown(response.output_text.replace("\n", "  \n")))
# Out:
# Which metric would you like to analyze? 10
# **GREAT CHOICE!** Here are a couple examples for the metric `<Fluency>`
# Below are **5 Fluency examples** from **5 (best)** to **1 (worst)**.
# Fluency focuses on **how smoothly and clearly the text is written**: grammar, word choice, sentence flow, and readability.
#
# ---
#
# ### 5 — Excellent Fluency
# **QUESTION:** Rewrite this customer update in a polished style.
# **ANSWER:** We’ve completed the system upgrade ahead of schedule, and service is now fully restored. If you experience any issues, please contact support.
# **SCORE:** 5
# **EXPLANATION:** The response is clear, concise, grammatically correct, and flows naturally. It is easy to read and professionally written.
#
# ---
#
# ### 4 — Good Fluency
# **QUESTION:** Write a short status update for the team.
# **ANSWER:** The project is moving well, and most tasks are done. A few final checks still need to be completed before release.
# **SCORE:** 4
# **EXPLANATION:** The writing is smooth and understandable with minor simplicity in sentence structure. It is fluent, though not especially varied or polished.
#
# ---
#
# ### 3 — Fair Fluency
# **QUESTION:** Summarize today’s meeting in one sentence.
# **ANSWER:** We talked about the deadline and the team agree to finish the work soon, but there was some confusion about the next steps.
# **SCORE:** 3
# **EXPLANATION:** The meaning is understandable, but there are grammatical issues and awkward phrasing. The text reads unevenly and is less polished.
#
# ---
#
# ### 2 — Poor Fluency
# **QUESTION:** Draft a brief email to confirm delivery.
# **ANSWER:** Delivery is confirmed. We did send the package and it arrive today, and hope everything is okay with you.
# **SCORE:** 2
# **EXPLANATION:** The response has noticeable grammar errors and awkward wording. The message can still be understood, but it is not smooth or well written.
#
# ---
#
# ### 1 — Very Poor Fluency
# **QUESTION:** Write a short apology note to a client.
# **ANSWER:** Sorry for delay. Meeting went bad and us no finish document. Please understanding and wait later.
# **SCORE:** 1
# **EXPLANATION:** The text is difficult to read due to major grammar errors, unnatural phrasing, and poor sentence structure. Communication is very unclear.
#
# ---
#
# If you want, I can now create the same **high-to-low graded examples** for the other 14 metrics in the same format.
